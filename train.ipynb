# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# Requirement already satisfied: ultralytics in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (8.3.140)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (3.10.3)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.7.0+cu128)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (0.22.0+cu128)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.8.0->ultralytics) (80.7.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied
appdata\local\programs\python\python313\lib\site-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\computer2day\appdata\local\programs\python\python313\lib\site-packages (from requests->roboflow) (3.3.2)

# %%
import shutil
from roboflow import Roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="ioCoYJX6vxALNJ3cUKBs")
project = rf.workspace("eagle-eye").project("basketball-1zhpe")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Basketball-1 to yolov8:: 100%|██████████| 68366/68366 [00:17<00:00, 3972.94it/s]
# Extracting Dataset Version Zip to Basketball-1 in yolov8:: 100%|██████████| 5210/5210 [00:03<00:00, 1391.36it/s]

# %%
import ultralytics
ultralytics.checks()

import torch

torch.cuda.empty_cache()
torch.no_grad()
# Out:
# Ultralytics 8.3.140  Python-3.13.3 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# Setup complete  (4 CPUs, 23.9 GB RAM, 299.8/953.2 GB disk)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    batch=4,
    plots=True,
    verbose=True
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.25M/6.25M [00:01<00:00, 5.27MB/s]
# New https://pypi.org/project/ultralytics/8.3.232 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.140  Python-3.13.3 torch-2.7.0+cu128 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=c:\Users\computer2day\Documents\GitHub\Swish-Vision\Basketball-1/data.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train11, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs\detect\train11, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, [64, 128, 256]]
# Model summary: 129 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[15], line 4
#       1 from ultralytics import YOLO
#       3 model = YOLO("yolov8n.pt")
# ----> 4 model.train(
#       5     data=f"{dataset.location}/data.yaml",
#       6     epochs=100,
#       7     imgsz=640,
#       8     batch=4,
#       9     plots=True,
#      10     verbose=True
#      11 )
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\model.py:793, in Model.train(self, trainer, **kwargs)
#     790     self.model = self.trainer.model
#     792 self.trainer.hub_session = self.session  # attach optional HUB session
# --> 793 self.trainer.train()
#     794 # Update model and cfg after training
#     795 if RANK in {-1, 0}:
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\trainer.py:211, in BaseTrainer.train(self)
#     208         ddp_cleanup(self, str(file))
#     210 else:
# --> 211     self._do_train(world_size)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\trainer.py:332, in BaseTrainer._do_train(self, world_size)
#     330 if world_size > 1:
#     331     self._setup_ddp(world_size)
# --> 332 self._setup_train(world_size)
#     334 nb = len(self.train_loader)  # number of batches
#     335 nw = max(round(self.args.warmup_epochs * nb), 100) if self.args.warmup_epochs > 0 else -1  # warmup iterations
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\trainer.py:269, in BaseTrainer._setup_train(self, world_size)
#     267 if self.amp and RANK in {-1, 0}:  # Single-GPU and DDP
#     268     callbacks_backup = callbacks.default_callbacks.copy()  # backup callbacks as check_amp() resets them
# --> 269     self.amp = torch.tensor(check_amp(self.model), device=self.device)
#     270     callbacks.default_callbacks = callbacks_backup  # restore callbacks
#     271 if RANK > -1 and world_size > 1:  # DDP
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\utils\checks.py:776, in check_amp(model)
#     773 try:
#     774     from ultralytics import YOLO
# --> 776     assert amp_allclose(YOLO("yolo11n.pt"), im)
#     777     LOGGER.info(f"{prefix}checks passed ✅")
#     778 except ConnectionError:
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\utils\checks.py:764, in check_amp.<locals>.amp_allclose(m, im)
#     762 batch = [im] * 8
#     763 imgsz = max(256, int(model.stride.max() * 4))  # max stride P5-32 and P6-64
# --> 764 a = m(batch, imgsz=imgsz, device=device, verbose=False)[0].boxes.data  # FP32 inference
#     765 with autocast(enabled=True):
#     766     b = m(batch, imgsz=imgsz, device=device, verbose=False)[0].boxes.data  # AMP inference
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\model.py:182, in Model.__call__(self, source, stream, **kwargs)
#     153 def __call__(
#     154     self,
#     155     source: Union[str, Path, int, Image.Image, list, tuple, np.ndarray, torch.Tensor] = None,
#     156     stream: bool = False,
#     157     **kwargs: Any,
#     158 ) -> list:
#     159     """
#     160     Alias for the predict method, enabling the model instance to be callable for predictions.
#     161
#    (...)    180         ...     print(f"Detected {len(r)} objects in image")
#     181     """
# --> 182     return self.predict(source, stream, **kwargs)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\model.py:552, in Model.predict(self, source, stream, predictor, **kwargs)
#     550 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     551     self.predictor.set_prompts(prompts)
# --> 552 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:218, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     216     return self.stream_inference(source, model, *args, **kwargs)
#     217 else:
# --> 218     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\engine\predictor.py:299, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     297 # Warmup model
#     298 if not self.done_warmup:
# --> 299     self.model.warmup(
#     300         imgsz=(1 if self.model.pt or self.model.triton else self.dataset.bs, self.model.ch, *self.imgsz)
#     301     )
#     302     self.done_warmup = True
#     304 self.seen, self.windows, self.batch = 0, [], None
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\autobackend.py:808, in AutoBackend.warmup(self, imgsz)
#     806 im = torch.empty(*imgsz, dtype=torch.half if self.fp16 else torch.float, device=self.device)  # input
#     807 for _ in range(2 if self.jit else 1):
# --> 808     self.forward(im)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\autobackend.py:592, in AutoBackend.forward(self, im, augment, visualize, embed, **kwargs)
#     590 # PyTorch
#     591 if self.pt or self.nn_module:
# --> 592     y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     594 # TorchScript
#     595 elif self.jit:
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:115, in BaseModel.forward(self, x, *args, **kwargs)
#     113 if isinstance(x, dict):  # for cases of training and validating while training.
#     114     return self.loss(x, *args, **kwargs)
# --> 115 return self.predict(x, *args, **kwargs)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:133, in BaseModel.predict(self, x, profile, visualize, augment, embed)
#     131 if augment:
#     132     return self._predict_augment(x)
# --> 133 return self._predict_once(x, profile, visualize, embed)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\tasks.py:156, in BaseModel._predict_once(self, x, profile, visualize, embed)
#     154 if profile:
#     155     self._profile_one_layer(m, x, dt)
# --> 156 x = m(x)  # run
#     157 y.append(x if m.i in self.save else None)  # save output
#     158 if visualize:
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\modules\head.py:76, in Detect.forward(self, x)
#      74 if self.training:  # Training path
#      75     return x
# ---> 76 y = self._inference(x)
#      77 return y if self.export else (y, x)
#
# File c:\Users\computer2day\AppData\Local\Programs\Python\Python313\Lib\site-packages\ultralytics\nn\modules\head.py:144, in Detect._inference(self, x)
#     141 else:
#     142     dbox = self.decode_bboxes(self.dfl(box), self.anchors.unsqueeze(0)) * self.strides
# --> 144 return torch.cat((dbox, cls.sigmoid()), 1)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 0 has a total capacity of 6.00 GiB of which 0 bytes is free. Of the allocated memory 13.55 GiB is allocated by PyTorch, and 128.86 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
